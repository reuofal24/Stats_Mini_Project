# %% [markdown]
# <a href="https://colab.research.google.com/github/reuofal24/Stats_Mini_Project/blob/main/Stats_Mini_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mini Project 🚀
# # Dataset Description:
# The Brazilian E-Commerce Public Dataset by Olist contains information about orders, customers, products, and payments from 2016 to 2018. It includes data on orders made at Olist Store.
#
# # We used Order Items dataset and for merge used Orders dataset📈

# %% [markdown]
# ## 1. Data Exploration and Preparation:✅
# * Load the necessary Python libraries (pandas, numpy, plotly express).
# * Load the dataset into a pandas DataFrame.
# * Explore the structure of the dataset (columns, datatypes, missing values).
# * Clean the data (handle missing values, data type conversions if necessary).

# %%
# Load necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as px

# %%
# URL of the dataset
url ="https://raw.githubusercontent.com/zain-codes/LeWagon-Datasets/main/olist_order_items_dataset.csv"

# Reading the dataset from the URL into a pandas DataFrame
df = pd.read_csv(url)
df
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
# Display information about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %%
# Summary statistics of the dataset
df.describe()
# Out:
#        order_item_id          price  freight_value
# count  112650.000000  112650.000000  112650.000000
# mean        1.197834     120.653739      19.990320
# std         0.705124     183.633928      15.806405
# min         1.000000       0.850000       0.000000
# 25%         1.000000      39.900000      13.080000
# 50%         1.000000      74.990000      16.260000
# 75%         1.000000     134.900000      21.150000
# max        21.000000    6735.000000     409.680000

# %%
# Check for null in dataset
df.isnull().sum()
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %% [markdown]
# **We notice there is no missing value and we don't want to change any type**

# %% [markdown]
# ## 2. Descriptive Statistics:✅
# * Compute basic statistics (mean, median, mode, standard deviation) for relevant columns (price).
# * Visualize distributions using histograms, boxplots.
# * Explore correlations between variables.

# %%
# Calculate the mean order price
mean_order_price = df.groupby('order_id')['price'].sum().mean()
print("Mean order price:", mean_order_price)
# Out:
# Mean order price: 137.7540763788945

# %%
# Calculate the median order price
median_order_price = df.groupby('order_id')['price'].sum().median()
print("Median order price:", median_order_price)
# Out:
# Median order price: 86.9

# %%
# Calculate the standard deviation order price
std_order_price = df.groupby('order_id')['price'].sum().std()
print("Standard deviation of order prices:", std_order_price)
# Out:
# Standard deviation of order prices: 210.64514531166344

# %%
# Calculate the mode order price
mode_order_price = df.groupby('order_id')['price'].sum().mode().iloc[0]
print("Mode order price:", mode_order_price)
# Out:
# Mode order price: 59.9

# %%
# Create a DataFrame for the statistics
stats_df = pd.DataFrame({
    'Statistic': ['Mean', 'Median', 'Mode', 'Standard Deviation'],
    'Value': [mean_order_price, median_order_price, mode_order_price, std_order_price]
})

# Visualize the statistics using a bar chart
fig = px.bar(stats_df, x='Statistic', y='Value', text='Value', color='Statistic',
             labels={'Statistic': 'Statistic', 'Value': 'Value'})
fig.update_traces(texttemplate='%{text:.2f}', textposition='outside')
fig.update_layout(title='Order Price Statistics')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Plot histogram for 'price' column using Plotly Express
fig = px.histogram(df, x='price', nbins=20, title='Distribution of Order Price',
                   labels={'order_price': 'Order Price', 'count': 'Frequency'})
fig.update_layout(xaxis=dict(title='Order Price'), yaxis=dict(title='Frequency'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Plot boxplot for 'price' column using Plotly Express
fig = px.box(df, y='price', title='Boxplot of Order Price')
fig.update_layout(yaxis=dict(title='Order Price'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# URL of the dataset
url_2 = "https://raw.githubusercontent.com/zain-codes/LeWagon-Datasets/main/olist_orders_dataset.csv"

# Reading the dataset from the URL into a pandas DataFrame
df2 = pd.read_csv(url_2)
df2
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
# Merge the datasets on the common key 'order_id'
merged_df = pd.merge(df, df2, on='order_id', how='inner')

# Convert timestamps to datetime objects
merged_df['order_purchase_timestamp'] = pd.to_datetime(merged_df['order_purchase_timestamp'])
merged_df['order_delivered_customer_date'] = pd.to_datetime(merged_df['order_delivered_customer_date'])

# Calculate shipping time
merged_df['shipping_time'] = merged_df['order_delivered_customer_date'] - merged_df['order_purchase_timestamp']

# Convert shipping time to days
merged_df['shipping_time_days'] = merged_df['shipping_time'].dt.days

# Explore correlation between order price and shipping time
correlation_coefficient = merged_df['price'].corr(merged_df['shipping_time_days'])
print("Correlation Coefficient between Order Price and Shipping Time:", correlation_coefficient)

# Plotting the correlation matrix as a heatmap using Plotly Express
fig = px.imshow(correlation_matrix,
                labels=dict(color="Correlation"),
                x=correlation_matrix.columns,
                y=correlation_matrix.columns,
                title="Correlation Matrix Heatmap")
fig.show()
# Out:
# Correlation Coefficient between Order Price and Shipping Time: 0.06228953850218645
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## 3. Hypothesis Testing (A/B Testing):✅
# * Hypothesis:
# The average order price (amount spent on orders) is the same for orders with different order states (e.g., delivered vs. canceled).
#
# * Null Hypothesis (H0):
# There is no difference in the average order price between different order states.
#
# * Alternative Hypothesis (H1):
# There is a difference in the average order price between different order states.

# %%
from scipy.stats import f_oneway

# Extract order prices for each order state
order_prices_delivered = merged_df[merged_df['order_status'] == 'delivered']['price']
order_prices_canceled = merged_df[merged_df['order_status'] == 'canceled']['price']
order_prices_processing = merged_df[merged_df['order_status'] == 'processing']['price']

# Perform ANOVA test
f_statistic, p_value = f_oneway(order_prices_delivered, order_prices_canceled, order_prices_processing)

# Print results
print("F-statistic:", f_statistic)
print("P-value:", p_value)

# Interpret results
alpha = 0.05
if p_value < alpha:
    print("Reject null hypothesis: There is a statistically significant difference in the average order prices between different order states.")
else:
    print("Fail to reject null hypothesis: There is no statistically significant difference in the average order prices between different order states.")
# Out:
# F-statistic: 37.66860697785281
# P-value: 4.428700627758244e-17
# Reject null hypothesis: There is a statistically significant difference in the average order prices between different order states.

# %% [markdown]
# ## 4. Visualization and Interpretation:✅
# * Visualize the results of hypothesis testing (e.g., bar chart).
# * Interpret the visualizations and relate them back to the hypothesis being tested.

# %%
# Calculate average order prices for each order state
avg_order_price_delivered = order_prices_delivered.mean()
avg_order_price_canceled = order_prices_canceled.mean()
avg_order_price_processing = order_prices_processing.mean()

# Create a DataFrame for visualization
data = {
    'Order State': ['Delivered', 'Canceled', 'Processing'],
    'Average Order Price': [avg_order_price_delivered, avg_order_price_canceled, avg_order_price_processing]
}

# Create a bar chart using Plotly Express
fig = px.bar(data, x='Order State', y='Average Order Price',
             title='Average Order Price by Order State',
             labels={'Average Order Price': 'Average Order Price'},
             color='Order State')

# Show the visualization
fig.show()

# Interpretation
alpha = 0.05
if p_value < alpha:
    print("The hypothesis test suggests rejecting the null hypothesis.")
    print("There is a statistically significant difference in the average order prices between different order states.")
else:
    print("The hypothesis test does not provide enough evidence to reject the null hypothesis.")
    print("There is no statistically significant difference in the average order prices between different order states.")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
